# %% [markdown]
# ## Merging DataFrames
#
# ### Series Object ( 1 dimensional, a row)
# ### Data Frame Object (2 dimensional, a table)
# ### Querying
#
# - iloc[], for querying based on position
# - loc[], for querying ow based on label
# - Queryin the DataFrame directly
#         - projecting a subset of columns
#         - using a boolean mask to filter data

# %%
import pandas as pd

# %%
# To add new data - df[column] = [a,b,c]
# To set default data (or overwrite all data): - df[column] = 2

df = pd.DataFrame([{'Name': 'Kris', 'Item Purchased': 'Cake', 'Cost': 12.50},
                   {'Name': 'Liz', 'Item Purchased': 'Whiskey', 'Cost': 6.00},
                   {'Name': 'Zac', 'Item Purchased': 'Guitar Strings', 'Cost': 4.00},
                   {'Name': 'Kristin', 'Item Purchased': 'Cigarttes', 'Cost': 6.00}],
                 index = ['Store 1', 'Store 1', 'Store 2', 'Store 1'])

# %%
df
# Out:
#          Cost  Item Purchased     Name
# Store 1  12.5            Cake     Kris
# Store 1   6.0         Whiskey      Liz
# Store 2   4.0  Guitar Strings      Zac
# Store 1   6.0       Cigarttes  Kristin

# %%
df['Date 1'] = ['December 1', 'January 1', 'Feb 1', 'March 1']

# %%
df
# Out:
#          Cost  Item Purchased     Name      Date 1
# Store 1  12.5            Cake     Kris  December 1
# Store 1   6.0         Whiskey      Liz   January 1
# Store 2   4.0  Guitar Strings      Zac       Feb 1
# Store 1   6.0       Cigarttes  Kristin     March 1

# %%
df['Delivered'] = True

# %%
df
# Out:
#          Cost  Item Purchased     Name      Date 1 Delivered
# Store 1  12.5            Cake     Kris  December 1      True
# Store 1   6.0         Whiskey      Liz   January 1      True
# Store 2   4.0  Guitar Strings      Zac       Feb 1      True
# Store 1   6.0       Cigarttes  Kristin     March 1      True

# %%
df['Feedback'] = ['Positive', None, 'Negative', None]

# %%
df
# Out:
#          Cost  Item Purchased     Name      Date 1 Delivered  Feedback
# Store 1  12.5            Cake     Kris  December 1      True  Positive
# Store 1   6.0         Whiskey      Liz   January 1      True      None
# Store 2   4.0  Guitar Strings      Zac       Feb 1      True  Negative
# Store 1   6.0       Cigarttes  Kristin     March 1      True      None

# %%
adf = df.reset_index() #nice approache

# %%
adf['Date 1'] = pd.Series({0: 'December 1', 2:'Mid-May'}) #ignores items we don't know 
# and adds new items.

# %%
adf
# Out:
#      index  Cost  Item Purchased     Name      Date 1 Delivered  Feedback
# 0  Store 1  12.5            Cake     Kris  December 1      True  Positive
# 1  Store 1   6.0         Whiskey      Liz         NaN      True      None
# 2  Store 2   4.0  Guitar Strings      Zac     Mid-May      True  Negative
# 3  Store 1   6.0       Cigarttes  Kristin         NaN      True      None

# %%
#full outer join (union)
#inner join (intersection)
#first create two data frames (staff, students)

staff_df = pd.DataFrame([{'Name': 'Kelly', 'Role': 'Director of HR'},
                         {'Name': 'Kevin', 'Role': 'Course Liason'},
                         {'Name': 'James', 'Role': 'Grader'}])
staff_df = staff_df.set_index('Name')
student_df = pd.DataFrame([{'Name': 'Mark', 'School': 'Business'},
                          {'Name': 'Kelly', 'School': 'Law'},
                          {'Name': 'James', 'School': 'Mathematics'}])
student_df = student_df.set_index('Name')
print(staff_df)
print()
print()
print(student_df)
# Out:
#                  Role
# Name
# Kelly  Director of HR
# Kevin   Course Liason
# James          Grader
# ()
# ()
#             School
# Name
# Mark      Business
# Kelly          Law
# James  Mathematics

# %%
pd.merge(staff_df, student_df, how='outer', left_index=True, right_index=True)
# union of dataframe
# Out:
#                  Role       School
# Name
# James          Grader  Mathematics
# Kelly  Director of HR          Law
# Kevin   Course Liason          NaN
# Mark              NaN     Business

# %%
pd.merge(staff_df, student_df, how='inner', left_index=True,right_index=True)
# intersectino of dataframe
# Out:
#                  Role       School
# Name
# Kelly  Director of HR          Law
# James          Grader  Mathematics

# %%
pd.merge(staff_df, student_df, how='left', left_index=True,right_index=True)
# Out:
#                  Role       School
# Name
# Kelly  Director of HR          Law
# Kevin   Course Liason          NaN
# James          Grader  Mathematics

# %%
pd.merge(staff_df,student_df, how='right', left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# Mark              NaN     Business
# Kelly  Director of HR          Law
# James          Grader  Mathematics

# %%
staff_df = staff_df.reset_index()
student_df = student_df.reset_index()
pd.merge(staff_df,student_df, how='left', left_on='Name', right_on='Name')
# Out:
#     Name            Role       School
# 0  Kelly  Director of HR          Law
# 1  Kevin   Course Liason          NaN
# 2  James          Grader  Mathematics

# %%
staff_df = pd.DataFrame([{'Name': 'Kelly', 'Role': 'Director of HR', 'Location': 'State Street'},
                         {'Name': 'Sally', 'Role': 'Course liasion', 'Location': 'Washington Avenue'},
                         {'Name': 'James', 'Role': 'Grader', 'Location': 'Washington Avenue'}])
student_df = pd.DataFrame([{'Name': 'James', 'School': 'Business', 'Location': '1024 Billiard Avenue'},
                           {'Name': 'Mike', 'School': 'Law', 'Location': 'Fraternity House #22'},
                           {'Name': 'Sally', 'School': 'Engineering', 'Location': '512 Wilson Crescent'}])
pd.merge(staff_df, student_df, how='left', left_on='Name', right_on='Name')
# Out:
#           Location_x   Name            Role            Location_y       School
# 0       State Street  Kelly  Director of HR                   NaN          NaN
# 1  Washington Avenue  Sally  Course liasion   512 Wilson Crescent  Engineering
# 2  Washington Avenue  James          Grader  1024 Billiard Avenue     Business

# %%
staff_df = pd.DataFrame([{'First Name': 'Kelly', 'Last Name': 'Desjardins', 'Role': 'Director of HR'},
                         {'First Name': 'Sally', 'Last Name': 'Brooks', 'Role': 'Course liasion'},
                         {'First Name': 'James', 'Last Name': 'Wilde', 'Role': 'Grader'}])
student_df = pd.DataFrame([{'First Name': 'James', 'Last Name': 'Hammond', 'School': 'Business'},
                           {'First Name': 'Mike', 'Last Name': 'Smith', 'School': 'Law'},
                           {'First Name': 'Sally', 'Last Name': 'Brooks', 'School': 'Engineering'}])
staff_df
student_df
pd.merge(staff_df, student_df, how='inner', left_on=['First Name','Last Name'], right_on=['First Name','Last Name'])
# Out:
#   First Name Last Name            Role       School
# 0      Sally    Brooks  Course liasion  Engineering

# %% [markdown]
# # Idiomatic Pandas: Making Code
# # Pandorable
# - Chaining indexing:
#     - df.loc['Washtenaw']['total population']
#     - Gnerally bad, pandas could return a copy of a view depending upon numpy
#
# - Code smell
#     - if you see a ][ you should think carefully about what you are doing (Tom Augspurger)

# %%
import pandas as pd 
df = pd.read_csv('census.csv')

# %%
df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY     STNAME             CTYNAME  \
# 0         40       3         6      1       0    Alabama             Alabama
# 1         50       3         6      1       1    Alabama      Autauga County
# 2         50       3         6      1       3    Alabama      Baldwin County
# 3         50       3         6      1       5    Alabama      Barbour County
# 4         50       3         6      1       7    Alabama         Bibb County
# 5         50       3         6      1       9    Alabama       Blount County
# 6         50       3         6      1      11    Alabama      Bullock County
# 7         50       3         6      1      13    Alabama       Butler County
# 8         50       3         6      1      15    Alabama      Calhoun County
# 9         50       3         6      1      17    Alabama     Chambers County
# 10        50       3         6      1      19    Alabama     Cherokee County
# ...

# %%
(df.where(df['SUMLEV'] == 50)
    .dropna()
    .set_index(['STNAME','CTYNAME'])
    .rename(columns={'ESTIMATESBASE2010': 'Estimates Base 2010'})) #pandas idiom
# Out:
#                               SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME    CTYNAME
# Alabama   Autauga County        50.0     3.0       6.0    1.0     1.0
#           Baldwin County        50.0     3.0       6.0    1.0     3.0
#           Barbour County        50.0     3.0       6.0    1.0     5.0
#           Bibb County           50.0     3.0       6.0    1.0     7.0
#           Blount County         50.0     3.0       6.0    1.0     9.0
#           Bullock County        50.0     3.0       6.0    1.0    11.0
#           Butler County         50.0     3.0       6.0    1.0    13.0
#           Calhoun County        50.0     3.0       6.0    1.0    15.0
#           Chambers County       50.0     3.0       6.0    1.0    17.0
#           Cherokee County       50.0     3.0       6.0    1.0    19.0
#           Chilton County        50.0     3.0       6.0    1.0    21.0
#           Choctaw County        50.0     3.0       6.0    1.0    23.0
# ...

# %%
df = df[df['SUMLEV']==50]
df.set_index(['STNAME','CTYNAME'], inplace=True)
df.rename(columns={'ESTIMATESBASE2010': 'Estimates Base 2010'}) #not pandas idiom
# Out:
#                               SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME    CTYNAME
# Alabama   Autauga County          50       3         6      1       1
#           Baldwin County          50       3         6      1       3
#           Barbour County          50       3         6      1       5
#           Bibb County             50       3         6      1       7
#           Blount County           50       3         6      1       9
#           Bullock County          50       3         6      1      11
#           Butler County           50       3         6      1      13
#           Calhoun County          50       3         6      1      15
#           Chambers County         50       3         6      1      17
#           Cherokee County         50       3         6      1      19
#           Chilton County          50       3         6      1      21
#           Choctaw County          50       3         6      1      23
# ...

# %%
import numpy as np

# %%
def min_max(row):
    data = row[['POPESTIMATE2010',
                'POPESTIMATE2011',
                'POPESTIMATE2012',
                'POPESTIMATE2013',
                'POPESTIMATE2014',
                'POPESTIMATE2015']]
    return pd.Series({'min': np.min(data), 'max': np.max(data)})

# %%
df.apply(min_max, axis=1) #index to use
# Out:
#                               SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME    CTYNAME
# Alabama   Autauga County        50.0     3.0       6.0    1.0     1.0
#           Baldwin County        50.0     3.0       6.0    1.0     3.0
#           Barbour County        50.0     3.0       6.0    1.0     5.0
#           Bibb County           50.0     3.0       6.0    1.0     7.0
#           Blount County         50.0     3.0       6.0    1.0     9.0
#           Bullock County        50.0     3.0       6.0    1.0    11.0
#           Butler County         50.0     3.0       6.0    1.0    13.0
#           Calhoun County        50.0     3.0       6.0    1.0    15.0
#           Chambers County       50.0     3.0       6.0    1.0    17.0
#           Cherokee County       50.0     3.0       6.0    1.0    19.0
#           Chilton County        50.0     3.0       6.0    1.0    21.0
#           Choctaw County        50.0     3.0       6.0    1.0    23.0
# ...

# %%
def min_max(row):
    data = row[['POPESTIMATE2010',
                'POPESTIMATE2011',
                'POPESTIMATE2012',
                'POPESTIMATE2013',
                'POPESTIMATE2014',
                'POPESTIMATE2015']]
    row['max'] = np.max(data)
    row['min'] = np.min(data)
    return row
df.apply(min_max, axis=1)
# Out:
#                               SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME    CTYNAME
# Alabama   Autauga County        50.0     3.0       6.0    1.0     1.0
#           Baldwin County        50.0     3.0       6.0    1.0     3.0
#           Barbour County        50.0     3.0       6.0    1.0     5.0
#           Bibb County           50.0     3.0       6.0    1.0     7.0
#           Blount County         50.0     3.0       6.0    1.0     9.0
#           Bullock County        50.0     3.0       6.0    1.0    11.0
#           Butler County         50.0     3.0       6.0    1.0    13.0
#           Calhoun County        50.0     3.0       6.0    1.0    15.0
#           Chambers County       50.0     3.0       6.0    1.0    17.0
#           Cherokee County       50.0     3.0       6.0    1.0    19.0
#           Chilton County        50.0     3.0       6.0    1.0    21.0
#           Choctaw County        50.0     3.0       6.0    1.0    23.0
# ...

# %%
rows = ['POPESTIMATE2010',
        'POPESTIMATE2011',
        'POPESTIMATE2012',
        'POPESTIMATE2013',
        'POPESTIMATE2014',
        'POPESTIMATE2015']
df.apply(lambda x: np.max(x[rows]), axis=1)
# Out:
# STNAME     CTYNAME
# Alabama    Autauga County         55347.0
#            Baldwin County        203709.0
#            Barbour County         27341.0
#            Bibb County            22861.0
#            Blount County          57776.0
#            Bullock County         10887.0
#            Butler County          20944.0
#            Calhoun County        118437.0
#            Chambers County        34153.0
#            Cherokee County        26084.0
#            Chilton County         43943.0
#            Choctaw County         13841.0
#            Clarke County          25767.0
#            Clay County            13880.0
#            Cleburne County        15072.0
#            Coffee County          51211.0
#            Colbert County         54514.0
#            Conecuh County         13208.0
#            Coosa County           11758.0
#            Covington County       38060.0
#            Crenshaw County        13963.0
#            Cullman County         82005.0
# ...

# %% [markdown]
# # Group By

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('census.csv')
df = df[df['SUMLEV']==50]
df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY     STNAME             CTYNAME  \
# 1         50       3         6      1       1    Alabama      Autauga County
# 2         50       3         6      1       3    Alabama      Baldwin County
# 3         50       3         6      1       5    Alabama      Barbour County
# 4         50       3         6      1       7    Alabama         Bibb County
# 5         50       3         6      1       9    Alabama       Blount County
# 6         50       3         6      1      11    Alabama      Bullock County
# 7         50       3         6      1      13    Alabama       Butler County
# 8         50       3         6      1      15    Alabama      Calhoun County
# 9         50       3         6      1      17    Alabama     Chambers County
# 10        50       3         6      1      19    Alabama     Cherokee County
# 11        50       3         6      1      21    Alabama      Chilton County
# ...

# %%
# %%timeit -n 10 
for state in df['STNAME'].unique():
    avg = np.average(df.where(df['STNAME'] == state).dropna()['CENSUS2010POP'])
    print('Counties in state ' + state + ' have an average population of ' + str(avg))
# Out:
# Counties in state Alabama have an average population of 71339.3432836
# Counties in state Alaska have an average population of 24490.7241379
# Counties in state Arizona have an average population of 426134.466667
# Counties in state Arkansas have an average population of 38878.9066667
# Counties in state California have an average population of 642309.586207
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.567164
# Counties in state Georgia have an average population of 60928.6352201
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.8636364
# ...

# %%
# %%timeit -n 10
for group, frame in df.groupby('STNAME'): 
    avg = np.average(frame['CENSUS2010POP'])
    print('Counties in state ' + group + 'have an average population of ' + str(avg))
# Out:
# Counties in state Alabamahave an average population of 71339.3432836
# Counties in state Alaskahave an average population of 24490.7241379
# Counties in state Arizonahave an average population of 426134.466667
# Counties in state Arkansashave an average population of 38878.9066667
# Counties in state Californiahave an average population of 642309.586207
# Counties in state Coloradohave an average population of 78581.1875
# Counties in state Connecticuthave an average population of 446762.125
# Counties in state Delawarehave an average population of 299311.333333
# Counties in state District of Columbiahave an average population of 601723.0
# Counties in state Floridahave an average population of 280616.567164
# Counties in state Georgiahave an average population of 60928.6352201
# Counties in state Hawaiihave an average population of 272060.2
# Counties in state Idahohave an average population of 35626.8636364
# Counties in state Illinoishave an average population of 125790.509804
# ...

# %%
df = df.set_index('STNAME')
def fun(item): 
    if item[0] < 'M': 
        return 0 
    if item[0] < 'Q': 
        return 1 
    return 2

# %%
for group, frame in df.groupby(fun): 
    print('There are ' + str(len(frame)) + ' records in group ' + str(group) + ' for processing ')
# Out:
# There are 1177 records in group 0 for processing
# There are 1134 records in group 1 for processing
# There are 831 records in group 2 for processing

# %%
df
# Out:
#            SUMLEV  REGION  DIVISION  STATE  COUNTY             CTYNAME  \
# STNAME
# Alabama        50       3         6      1       1      Autauga County
# Alabama        50       3         6      1       3      Baldwin County
# Alabama        50       3         6      1       5      Barbour County
# Alabama        50       3         6      1       7         Bibb County
# Alabama        50       3         6      1       9       Blount County
# Alabama        50       3         6      1      11      Bullock County
# Alabama        50       3         6      1      13       Butler County
# Alabama        50       3         6      1      15      Calhoun County
# Alabama        50       3         6      1      17     Chambers County
# Alabama        50       3         6      1      19     Cherokee County
# Alabama        50       3         6      1      21      Chilton County
# Alabama        50       3         6      1      23      Choctaw County
# ...

# %%
# quiz: print(df.groupby('Category').apply(lambda df,a,b: sum(df[a] * df[b]), 'Weight (oz.)', 'Quantity'))

# %%
df = pd.read_csv('census.csv')
df = df[df['SUMLEV']==50]

# %%
df.groupby('STNAME').agg({'CENSUS2010POP': np.average})
# Out:
#                       CENSUS2010POP
# STNAME
# Alabama                71339.343284
# Alaska                 24490.724138
# Arizona               426134.466667
# Arkansas               38878.906667
# California            642309.586207
# Colorado               78581.187500
# Connecticut           446762.125000
# Delaware              299311.333333
# District of Columbia  601723.000000
# Florida               280616.567164
# Georgia                60928.635220
# Hawaii                272060.200000
# Idaho                  35626.863636
# Illinois              125790.509804
# Indiana                70476.108696
# Iowa                   30771.262626
# Kansas                 27172.552381
# Kentucky               36161.391667
# Louisiana              70833.937500
# Maine                  83022.562500
# Maryland              240564.666667
# Massachusetts         467687.785714
# Michigan              119080.000000
# Minnesota              60964.655172
# Mississippi            36186.548780
# ...

# %%
print type(df.groupby(level=0)['POPESTIMATE2010','POPESTIMATE2011'])
# Out:
# <class 'pandas.core.groupby.DataFrameGroupBy'>

# %%
print type(df.groupby(level=0)['POPESTIMATE2010'])
# Out:
# <class 'pandas.core.groupby.SeriesGroupBy'>

# %%
(df.set_index('STNAME').groupby(level=0)['CENSUS2010POP'].agg({'avg': np.average, 'sum': np.sum}))
# Out:
#                            sum            avg
# STNAME
# Alabama                4779736   71339.343284
# Alaska                  710231   24490.724138
# Arizona                6392017  426134.466667
# Arkansas               2915918   38878.906667
# California            37253956  642309.586207
# Colorado               5029196   78581.187500
# Connecticut            3574097  446762.125000
# Delaware                897934  299311.333333
# District of Columbia    601723  601723.000000
# Florida               18801310  280616.567164
# Georgia                9687653   60928.635220
# Hawaii                 1360301  272060.200000
# Idaho                  1567582   35626.863636
# Illinois              12830632  125790.509804
# Indiana                6483802   70476.108696
# Iowa                   3046355   30771.262626
# Kansas                 2853118   27172.552381
# Kentucky               4339367   36161.391667
# Louisiana              4533372   70833.937500
# ...

# %%
(df.set_index('STNAME').groupby(level=0)['POPESTIMATE2010','POPESTIMATE2011'].agg({'avg': np.average, 'sum': np.sum}))
# Out:
#                                  sum                             avg  \
#                      POPESTIMATE2010 POPESTIMATE2011 POPESTIMATE2010
# STNAME
# Alabama                      4785161         4801108    71420.313433
# Alaska                        714021          722720    24621.413793
# Arizona                      6408208         6468732   427213.866667
# Arkansas                     2922394         2938538    38965.253333
# California                  37334079        37700034   643691.017241
# Colorado                     5048254         5119480    78878.968750
# Connecticut                  3579717         3589759   447464.625000
# Delaware                      899791          907916   299930.333333
# District of Columbia          605126          620472   605126.000000
# Florida                     18849890        19105533   281341.641791
# Georgia                      9713454         9812280    61090.905660
# ...

# %%
df.groupby('STNAME').POPESTIMATE2011.min()
# Out:
# STNAME
# Alabama                   8910
# Alaska                     651
# Arizona                   8589
# Arkansas                  5286
# California                1111
# Colorado                   697
# Connecticut             118418
# Delaware                165242
# District of Columbia    620472
# Florida                   8227
# Georgia                   1706
# Hawaii                      90
# Idaho                      951
# Illinois                  4282
# Indiana                   6086
# Iowa                      3996
# Kansas                    1252
# Kentucky                  2287
# Louisiana                 5086
# Maine                    17359
# Maryland                 20237
# Massachusetts            10141
# Michigan                  2230
# Minnesota                 3514
# Mississippi               1391
# Missouri                  2126
# Montana                    490
# Nebraska                   469
# Nevada                     758
# New Hampshire            32478
# ...

# %% [markdown]
# ## (a,b) (c,d): Scales
#
# - Ratio Scale:
#     - units are equally spaced
#     - mathematical operations of +/-/* are all valid
#     - E.g. height and weights
# - Interval Scale:
#     - units are equally spaced, there is no true zero
# - Ordinal Scale:
#     - the order of the units is important, but not evenly spaced.
#     - Letter grades such as A+, A are good examples
# - Nominal Scale:
#     - categories of data but the categories have no order with respect to one another.
#     - E.g. Teams of sport

# %%
# categorical data: 
df = pd.DataFrame(['A+','A','A-','B+','B','B-','C+','C','C-','D+','D'],
                 index=['excellent', 'excellent', 'excellent', 'good','good','good',
                       'ok','ok','ok','poor','poor'])

df.rename(columns={0:'Grades'}, inplace =True)
df
# Out:
#           Grades
# excellent     A+
# excellent      A
# excellent     A-
# good          B+
# good           B
# good          B-
# ok            C+
# ok             C
# ok            C-
# poor          D+
# poor           D

# %%
df['Grades'].astype('category').head() #categorical data example
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# Name: Grades, dtype: category
# Categories (11, object): [A, A+, A-, B, ..., C+, C-, D, D+]

# %%
grades = df['Grades'].astype('category', 
                              categories = ['D','D+', 'C-','C', 'C+','B-','B','B+','A-','A','A+'],
                              ordered=True)
grades.head()
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# Name: Grades, dtype: category
# Categories (11, object): [D < D+ < C- < C ... B+ < A- < A < A+]

# %%
grades > 'C' #boolean ordering
# Out:
# excellent     True
# excellent     True
# excellent     True
# good          True
# good          True
# good          True
# ok            True
# ok           False
# ok           False
# poor         False
# poor         False
# Name: Grades, dtype: bool

# %%
'''Here is casting example from a series to categorical 
   with the ordering Low < Medium < High.'''

s = pd.Series(['Low', 'Low', 'High', 'Medium', 'Low', 'High', 'Low'])
categorical = s.astype('category', 
                       categories = ['Low','Medium','High'], 
                       ordered=True) 
print(categorical) 
print(categorical > 'Low')
# Out:
# 0       Low
# 1       Low
# 2      High
# 3    Medium
# 4       Low
# 5      High
# 6       Low
# dtype: category
# Categories (3, object): [Low < Medium < High]
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# 5     True
# 6    False
# dtype: bool

# %%
import numpy as np
df = pd.read_csv('census.csv')
df = df[df['SUMLEV'] == 50]

# %%
df = df.set_index('STNAME').groupby(level=0)['CENSUS2010POP'].agg({'avg': np.average})
pd.cut(df['avg'], 10)
# Out:
# STNAME
# Alabama                  (11706.0871, 75333.413]
# Alaska                   (11706.0871, 75333.413]
# Arizona                 (390320.176, 453317.529]
# Arkansas                 (11706.0871, 75333.413]
# California              (579312.234, 642309.586]
# Colorado                 (75333.413, 138330.766]
# Connecticut             (390320.176, 453317.529]
# Delaware                (264325.471, 327322.823]
# District of Columbia    (579312.234, 642309.586]
# Florida                 (264325.471, 327322.823]
# Georgia                  (11706.0871, 75333.413]
# Hawaii                  (264325.471, 327322.823]
# Idaho                    (11706.0871, 75333.413]
# Illinois                 (75333.413, 138330.766]
# Indiana                  (11706.0871, 75333.413]
# Iowa                     (11706.0871, 75333.413]
# Kansas                   (11706.0871, 75333.413]
# Kentucky                 (11706.0871, 75333.413]
# Louisiana                (11706.0871, 75333.413]
# ...

# %%
#ex cutting: 
"""Use pd.cut to bin this data into 3 bins"""
s = pd.Series([168, 180, 174, 190, 170, 185, 179, 181, 175, 169, 182, 177, 180, 171])
bin_data = pd.cut(s,3)
print(bin_data)
# Out:
# 0     (167.978, 175.333]
# 1     (175.333, 182.667]
# 2     (167.978, 175.333]
# 3         (182.667, 190]
# 4     (167.978, 175.333]
# 5         (182.667, 190]
# 6     (175.333, 182.667]
# 7     (175.333, 182.667]
# 8     (167.978, 175.333]
# 9     (167.978, 175.333]
# 10    (175.333, 182.667]
# 11    (175.333, 182.667]
# 12    (175.333, 182.667]
# 13    (167.978, 175.333]
# dtype: category
# Categories (3, object): [(167.978, 175.333] < (175.333, 182.667] < (182.667, 190]]

# %% [markdown]
# ## Pivot Tables

# %%
df = pd.read_csv('cars.csv')

# %%
df.head()
# Out:
#    YEAR        Make           Model        Size  (kW) Unnamed: 5 TYPE  \
# 0  2012  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 1  2012      NISSAN            LEAF    MID-SIZE    80         A1    B
# 2  2013        FORD  FOCUS ELECTRIC     COMPACT   107         A1    B
# 3  2013  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 4  2013      NISSAN            LEAF    MID-SIZE    80         A1    B
#
#    CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  \
# 0               16.9              21.4               18.7               1.9
# 1               19.3              23.0               21.1               2.2
# 2               19.0              21.1               20.0               2.1
# 3               16.9              21.4               18.7               1.9
# 4               19.3              23.0               21.1               2.2
#
#    HWY (Le/100 km)  COMB (Le/100 km)  (g/km) RATING  (km)  TIME (h)
# ...

# %%
pivot_table = df.pivot_table(values='(kW)', index='YEAR',columns='Make',aggfunc=np.mean)

# %%
pivot_table
# Out:
# Make    BMW  CHEVROLET   FORD   KIA  MITSUBISHI  NISSAN  SMART       TESLA
# YEAR
# 2012    NaN        NaN    NaN   NaN        49.0    80.0    NaN         NaN
# 2013    NaN        NaN  107.0   NaN        49.0    80.0   35.0  280.000000
# 2014    NaN      104.0  107.0   NaN        49.0    80.0   35.0  268.333333
# 2015  125.0      104.0  107.0  81.0        49.0    80.0   35.0  320.666667
# 2016  125.0      104.0  107.0  81.0        49.0    80.0   35.0  409.700000

# %%
df.pivot_table(values='(kW)',index ='YEAR', columns ='Make', aggfunc=[np.mean,np.min], margins=True)
# Out:
#        mean                                                             \
# Make    BMW CHEVROLET   FORD   KIA MITSUBISHI NISSAN SMART       TESLA
# YEAR
# 2012    NaN       NaN    NaN   NaN       49.0   80.0   NaN         NaN
# 2013    NaN       NaN  107.0   NaN       49.0   80.0  35.0  280.000000
# 2014    NaN     104.0  107.0   NaN       49.0   80.0  35.0  268.333333
# 2015  125.0     104.0  107.0  81.0       49.0   80.0  35.0  320.666667
# 2016  125.0     104.0  107.0  81.0       49.0   80.0  35.0  409.700000
# All   125.0     104.0  107.0  81.0       49.0   80.0  35.0  345.478261
#
#                    amin                                                        \
# Make         All    BMW CHEVROLET   FORD   KIA MITSUBISHI NISSAN SMART  TESLA
# YEAR
# 2012   64.500000    NaN       NaN    NaN   NaN       49.0   80.0   NaN    NaN
# 2013  158.444444    NaN       NaN  107.0   NaN       49.0   80.0  35.0  270.0
# ...

# %% [markdown]
# ## Date Functionality

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Timestamp

# %%
pd.Timestamp('9/1/2016 10:05AM')
# Out:
# Timestamp('2016-09-01 10:05:00')

# %% [markdown]
# ### Period

# %%
pd.Period('1/2016')
# Out:
# Period('2016-01', 'M')

# %%
pd.Period('3/5/2016')
# Out:
# Period('2016-03-05', 'D')

# %% [markdown]
# ### Datetimeindex

# %%
t1 = pd.Series(list('abc'), [pd.Timestamp('2016-09-01'), pd.Timestamp('2016-09-02'), pd.Timestamp('2016-09-03')])

# %%
t1
# Out:
# 2016-09-01    a
# 2016-09-02    b
# 2016-09-03    c
# dtype: object

# %%
type(t1.index)
# Out:
# pandas.tseries.index.DatetimeIndex

# %% [markdown]
# ### PeriodIndex

# %%
t2 = pd.Series(list('def'), [pd.Period('2016-09'),pd.Period('2016-10'), pd.Period('2016-11')])
t2
# Out:
# 2016-09    d
# 2016-10    e
# 2016-11    f
# Freq: M, dtype: object

# %%
type(t2.index)
# Out:
# pandas.tseries.period.PeriodIndex

# %% [markdown]
# ### Conerting to Datetime

# %%
d1 = ['2 June 2013', 'Aug 29, 2014', '2015-06-26', '7/12/16']
ts3 = pd.DataFrame(np.random.randint(10,100,(4,2)), index = d1, columns=list('ab'))
ts3
# Out:
#                a   b
# 2 June 2013   87  91
# Aug 29, 2014  31  24
# 2015-06-26    80  94
# 7/12/16       52  98

# %%
ts3.index = pd.to_datetime(ts3.index)

# %%
ts3
# Out:
#              a   b
# 2013-06-02  87  91
# 2014-08-29  31  24
# 2015-06-26  80  94
# 2016-07-12  52  98

# %%
pd.to_datetime('4.7.12', dayfirst=True)
# Out:
# Timestamp('2012-07-04 00:00:00')

# %% [markdown]
# ### Timedeltas

# %%
pd.Timestamp('9/3/2016')-pd.Timestamp('9/1/2016')
# Out:
# Timedelta('2 days 00:00:00')

# %%
pd.Timestamp('9/2/2016 8:10AM') + pd.Timedelta('12D 3H')
# Out:
# Timestamp('2016-09-14 11:10:00')

# %% [markdown]
# ### Working with Dates in a DataFrame

# %%
dates = pd.date_range('10-01-2016', periods=9, freq='2W-SUN')
dates
# Out:
# DatetimeIndex(['2016-10-02', '2016-10-16', '2016-10-30', '2016-11-13',
#                '2016-11-27', '2016-12-11', '2016-12-25', '2017-01-08',
#                '2017-01-22'],
#               dtype='datetime64[ns]', freq='2W-SUN')

# %%
df = pd.DataFrame({'Count 1': 100 + np.random.randint(-5,10,9).cumsum(), 
                   'Count 2': 120 + np.random.randint(-5,10,9)}, index=dates)
df
# Out:
#             Count 1  Count 2
# 2016-10-02      107      117
# 2016-10-16      113      127
# 2016-10-30      119      117
# 2016-11-13      126      126
# 2016-11-27      128      129
# 2016-12-11      124      124
# 2016-12-25      120      120
# 2017-01-08      122      123
# 2017-01-22      122      119

# %%
df.index.weekday_name
# Out:
# array(['Sunday', 'Sunday', 'Sunday', 'Sunday', 'Sunday', 'Sunday',
#        'Sunday', 'Sunday', 'Sunday'], dtype=object)

# %%
df.diff()
# Out:
#             Count 1  Count 2
# 2016-10-02      NaN      NaN
# 2016-10-16      6.0     10.0
# 2016-10-30      6.0    -10.0
# 2016-11-13      7.0      9.0
# 2016-11-27      2.0      3.0
# 2016-12-11     -4.0     -5.0
# 2016-12-25     -4.0     -4.0
# 2017-01-08      2.0      3.0
# 2017-01-22      0.0     -4.0

# %%
df.resample('M').mean()
# Out:
#             Count 1     Count 2
# 2016-10-31    113.0  120.333333
# 2016-11-30    127.0  127.500000
# 2016-12-31    122.0  122.000000
# 2017-01-31    122.0  121.000000

# %%
df['2017']
# Out:
#             Count 1  Count 2
# 2017-01-08      122      123
# 2017-01-22      122      119

# %%
df['2016-12']
# Out:
#             Count 1  Count 2
# 2016-12-11      124      124
# 2016-12-25      120      120

# %%
df['2016-12': ]
# Out:
#             Count 1  Count 2
# 2016-12-11      124      124
# 2016-12-25      120      120
# 2017-01-08      122      123
# 2017-01-22      122      119

# %%
df.asfreq('W',method='ffill')
# Out:
#             Count 1  Count 2
# 2016-10-02      107      117
# 2016-10-09      107      117
# 2016-10-16      113      127
# 2016-10-23      113      127
# 2016-10-30      119      117
# 2016-11-06      119      117
# 2016-11-13      126      126
# 2016-11-20      126      126
# 2016-11-27      128      129
# 2016-12-04      128      129
# 2016-12-11      124      124
# 2016-12-18      124      124
# 2016-12-25      120      120
# 2017-01-01      120      120
# 2017-01-08      122      123
# 2017-01-15      122      123
# 2017-01-22      122      119

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 

df.plot()
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
